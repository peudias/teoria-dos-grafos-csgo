# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Definições iniciais
minRivalry = 50  # Limiar para considerar uma conexão significativa

# Carregar dados do CSV
df = pd.read_csv('../db/results.csv')

# Criar um grafo não direcionado
G = nx.Graph()

# Adicionar arestas ao grafo com base nas partidas
for index, row in df.iterrows():
    # Adiciona arestas entre team_1 e team_2
    # Se a aresta já existir, aumenta o peso (representando outra partida)
    if G.has_edge(row['team_1'], row['team_2']):
        G.edges[row['team_1'], row['team_2']]['weight'] += 1
    else:
        G.add_edge(row['team_1'], row['team_2'], weight=1)

# Filtrar arestas com peso maior que {minRivalry}
# Criar uma cópia do grafo para modificar
H = nx.Graph()
for u, v, data in G.edges(data=True):
    if data['weight'] > minRivalry:
        H.add_edge(u, v, weight=data['weight'])

# Agora H contém apenas as arestas com peso maior que {minRivalry}

# Visualização
if len(H) > 0:  # Se o grafo não estiver vazio
    plt.figure(figsize=(12, 12))
    pos = nx.spring_layout(H)  # Posicionamento dos nós
    nx.draw_networkx_nodes(H, pos)
    nx.draw_networkx_edges(H, pos)
    nx.draw_networkx_labels(H, pos)
    plt.title('Rede de Competição de CSGO com Conexões Fortes')
    plt.axis('off')  # Desliga os eixos
    plt.show()
else:
    print(f"Não existem conexões com peso acima de {minRivalry} no grafo.")

# %%
# Strength of Ties
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Definições iniciais
minRivalry = 11  # Limiar para considerar uma conexão significativa

# Carregar dados do CSV
df = pd.read_csv('../db/results.csv')

# Convertendo as colunas de resultado para inteiros
df['result_1'] = pd.to_numeric(df['result_1'], errors='coerce')
df['result_2'] = pd.to_numeric(df['result_2'], errors='coerce')

# Criar um grafo não direcionado
G = nx.Graph()

# Adicionar arestas ao grafo com base nas partidas
for index, row in df.iterrows():
    # Calcular o peso com base na diferença de pontuação
    score_diff = abs(row['result_1'] - row['result_2'])
    weight = 1 if score_diff == 0 else 1 / score_diff  # Evitar divisão por zero
    
    # Verifica quem é o vencedor e ajusta o peso se necessário
    # Considerando que map_winner seja '1' ou '2', indicando o vencedor
    if row['map_winner'] == '1':  # Se team_1 é o vencedor
        weight += 1
    elif row['map_winner'] == '2':  # Se team_2 é o vencedor
        weight += 1
    
    # Adiciona ou atualiza a aresta com o novo peso
    if G.has_edge(row['team_1'], row['team_2']):
        G.edges[row['team_1'], row['team_2']]['weight'] += weight
    else:
        G.add_edge(row['team_1'], row['team_2'], weight=weight)

# Filtrar arestas com peso maior que o limiar de rivalidade
H = nx.Graph()
for u, v, data in G.edges(data=True):
    if data['weight'] > minRivalry:
        H.add_edge(u, v, weight=data['weight'])

# Visualização
if len(H) > 0:
    plt.figure(figsize=(12, 12))
    pos = nx.spring_layout(H)
    nx.draw_networkx_nodes(H, pos)
    nx.draw_networkx_edges(H, pos)
    nx.draw_networkx_labels(H, pos)
    plt.title('Rede de Competição de CSGO com Conexões Fortes')
    plt.axis('off')
    plt.show()
else:
    print(f"Não existem conexões com peso acima de {minRivalry} no grafo.")

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Define equipe para analisar
team_to_analyze = 'FaZe'

# Carregar dados do CSV
df = pd.read_csv('../db/results.csv')

# Converter as datas para o tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Filtrar as partidas que incluem a equipe de interesse
df_team = df[(df['team_1'] == team_to_analyze) | (df['team_2'] == team_to_analyze)]

# Criar um grafo para cada data em que a equipe de interesse jogou
graphs_by_date = {}
for date, group in df_team.groupby('date'):
    G = nx.Graph()
    for i, row in group.iterrows():
        # Adiciona equipe adversária como nó no grafo
        opponent = row['team_2'] if row['team_1'] == team_to_analyze else row['team_1']
        G.add_edge(team_to_analyze, opponent, weight=1)
    graphs_by_date[date] = G

# Agora é possível analisar cada grafo para ver com quais equipes a equipe de interesse jogou em cada data
# Aqui imprime os oponentes e a data de cada jogo
for date, graph in graphs_by_date.items():
    opponents = list(nx.neighbors(graph, team_to_analyze))
    print(f"Em {date.date()}, {team_to_analyze} jogou contra: {opponents}")

# Para visualizar as conexões de uma data específica, insira a data aqui:
specific_date = pd.to_datetime('2020-03-18')

# Verifica se a equipe jogou nessa data e cria uma visualização
if specific_date in graphs_by_date:
    plt.figure(figsize=(8, 5))
    H = graphs_by_date[specific_date]
    pos = nx.spring_layout(H)
    nx.draw_networkx_nodes(H, pos, node_size=700, node_color='lightblue')
    nx.draw_networkx_edges(H, pos, edge_color='gray')
    nx.draw_networkx_labels(H, pos, font_size=12)
    plt.title(f'Conexões de {team_to_analyze} em {specific_date.date()}')
    plt.axis('off')
    plt.show()
else:
    print(f"{team_to_analyze} não jogou em {specific_date.date()}.")
# Out:
# Em 2016-01-22, FaZe jogou contra: ['Luminosity', 'Natus Vincere']
# Em 2016-01-23, FaZe jogou contra: ['Luminosity']
# Em 2016-02-10, FaZe jogou contra: ['Virtus.pro']
# Em 2016-03-03, FaZe jogou contra: ['E-frag.net', 'Tempo Storm', 'Virtus.pro', 'Astralis', 'Envy']
# Em 2016-03-08, FaZe jogou contra: ['NiP']
# Em 2016-03-10, FaZe jogou contra: ['Natus Vincere']
# Em 2016-03-12, FaZe jogou contra: ['SK']
# Em 2016-03-13, FaZe jogou contra: ['SK']
# Em 2016-03-17, FaZe jogou contra: ['G2']
# Em 2016-03-19, FaZe jogou contra: ['mousesports']
# Em 2016-03-29, FaZe jogou contra: ['Liquid']
# Em 2016-03-30, FaZe jogou contra: ['Splyce']
# Em 2016-03-31, FaZe jogou contra: ['fnatic']
# Em 2016-04-12, FaZe jogou contra: ['Virtus.pro']
# Em 2016-04-13, FaZe jogou contra: ['Envy']
# Em 2016-04-19, FaZe jogou contra: ['Virtus.pro', 'Astralis']
# Em 2016-04-20, FaZe jogou contra: ['Envy', 'fnatic']
# Em 2016-04-21, FaZe jogou contra: ['FlipSid3', 'Dignitas']
# Em 2016-04-24, FaZe jogou contra: ['fnatic']
# Em 2016-04-26, FaZe jogou contra: ['Envy']
# Em 2016-04-29, FaZe jogou contra: ['mousesports']
# Em 2016-05-04, FaZe jogou contra: ['G2']
# Em 2016-05-05, FaZe jogou contra: ['Dignitas']
# Em 2016-05-20, FaZe jogou contra: ['Astralis']
# Em 2016-05-22, FaZe jogou contra: ['NiP']
# Em 2016-05-25, FaZe jogou contra: ['mousesports']
# Em 2016-05-26, FaZe jogou contra: ['NiP']
# Em 2016-06-09, FaZe jogou contra: ['Dignitas']
# Em 2016-06-10, FaZe jogou contra: ['FlipSid3']
# Em 2016-06-11, FaZe jogou contra: ['Gambit']
# Em 2016-06-14, FaZe jogou contra: ['Dignitas', 'fnatic']
# Em 2016-06-15, FaZe jogou contra: ['TSM']
# Em 2016-06-16, FaZe jogou contra: ['Dignitas']
# Em 2016-06-18, FaZe jogou contra: ['fnatic']
# Em 2016-07-05, FaZe jogou contra: ['fnatic']
# Em 2016-07-06, FaZe jogou contra: ['SK']
# Em 2016-07-07, FaZe jogou contra: ['fnatic']
# Em 2016-07-15, FaZe jogou contra: ['CLG']
# Em 2016-07-16, FaZe jogou contra: ['mousesports']
# Em 2016-08-17, FaZe jogou contra: ['X']
# Em 2016-08-18, FaZe jogou contra: ['Virtus.pro']
# Em 2016-08-20, FaZe jogou contra: ['Envy']
# Em 2016-08-21, FaZe jogou contra: ['G2']
# Em 2016-08-25, FaZe jogou contra: ['NiP']
# Em 2016-08-30, FaZe jogou contra: ['Astralis', 'Space Soldiers']
# Em 2016-08-31, FaZe jogou contra: ['Astralis']
# Em 2016-09-01, FaZe jogou contra: ['Wizards']
# Em 2016-09-04, FaZe jogou contra: ['GODSENT', 'Astralis', 'mousesports']
# Em 2016-09-06, FaZe jogou contra: ['PENTA']
# Em 2016-09-07, FaZe jogou contra: ['CHAOS', 'FlipSid3', 'fnatic']
# Em 2016-09-08, FaZe jogou contra: ['G2', 'HellRaisers']
# Em 2016-09-09, FaZe jogou contra: ['FlipSid3']
# Em 2016-09-13, FaZe jogou contra: ['mousesports']
# Em 2016-09-16, FaZe jogou contra: ['Cloud9', 'Dignitas']
# Em 2016-09-17, FaZe jogou contra: ['Dignitas']
# Em 2016-09-20, FaZe jogou contra: ['GODSENT']
# Em 2016-09-25, FaZe jogou contra: ['Dignitas']
# Em 2016-10-11, FaZe jogou contra: ['Dignitas']
# Em 2016-10-12, FaZe jogou contra: ['Gambit', 'HellRaisers', 'Natus Vincere']
# Em 2016-10-13, FaZe jogou contra: ['Natus Vincere', 'FlipSid3']
# Em 2016-10-15, FaZe jogou contra: ['Virtus.pro']
# Em 2016-10-22, FaZe jogou contra: ['Cloud9', 'Immortals']
# Em 2016-10-26, FaZe jogou contra: ['Cloud9']
# Em 2016-10-27, FaZe jogou contra: ['Dignitas', 'SK']
# Em 2016-10-28, FaZe jogou contra: ['NRG']
# Em 2016-10-29, FaZe jogou contra: ['NiP']
# Em 2016-11-06, FaZe jogou contra: ['Envy']
# Em 2016-11-07, FaZe jogou contra: ['Astralis']
# Em 2016-11-08, FaZe jogou contra: ['fnatic']
# Em 2016-11-10, FaZe jogou contra: ['mousesports']
# Em 2016-11-12, FaZe jogou contra: ['Immortals']
# Em 2016-11-13, FaZe jogou contra: ['TSM', 'Renegades']
# Em 2016-11-17, FaZe jogou contra: ['Cloud9', 'Heroic']
# Em 2016-11-18, FaZe jogou contra: ['mousesports', 'SK', 'NiP']
# Em 2016-11-20, FaZe jogou contra: ['NiP']
# Em 2016-11-23, FaZe jogou contra: ['G2']
# Em 2016-11-24, FaZe jogou contra: ['NiP']
# Em 2016-11-26, FaZe jogou contra: ['GODSENT']
# Em 2016-12-01, FaZe jogou contra: ['Virtus.pro']
# Em 2016-12-03, FaZe jogou contra: ['OpTic']
# Em 2016-12-09, FaZe jogou contra: ['Astralis', 'Cloud9']
# Em 2016-12-11, FaZe jogou contra: ['OpTic']
# Em 2016-12-15, FaZe jogou contra: ['Cloud9']
# Em 2016-12-17, FaZe jogou contra: ['OpTic', 'Immortals']
# Em 2017-01-09, FaZe jogou contra: ['EPG', 'FlipSid3']
# Em 2017-01-23, FaZe jogou contra: ['SK', 'FlipSid3']
# Em 2017-01-24, FaZe jogou contra: ['Liquid']
# Em 2017-01-25, FaZe jogou contra: ['Gambit']
# Em 2017-01-26, FaZe jogou contra: ['Envy']
# Em 2017-01-28, FaZe jogou contra: ['SK']
# Em 2017-02-07, FaZe jogou contra: ['Kinguin']
# Em 2017-02-08, FaZe jogou contra: ['Heroic']
# Em 2017-02-09, FaZe jogou contra: ['Envy']
# Em 2017-02-16, FaZe jogou contra: ['Renegades']
# Em 2017-02-17, FaZe jogou contra: ['mousesports']
# Em 2017-02-18, FaZe jogou contra: ['Natus Vincere']
# Em 2017-03-01, FaZe jogou contra: ['Immortals', 'fnatic', 'NiP', 'Astralis', 'OpTic']
# Em 2017-03-04, FaZe jogou contra: ['Immortals']
# Em 2017-03-05, FaZe jogou contra: ['Astralis']
# Em 2017-03-09, FaZe jogou contra: ['NiP']
# Em 2017-03-21, FaZe jogou contra: ['Natus Vincere', 'LDLC']
# Em 2017-03-23, FaZe jogou contra: ['Astralis']
# Em 2017-03-30, FaZe jogou contra: ['fnatic']
# Em 2017-04-04, FaZe jogou contra: ['HellRaisers']
# Em 2017-04-05, FaZe jogou contra: ['Immortals']
# Em 2017-04-06, FaZe jogou contra: ['Gambit']
# Em 2017-04-07, FaZe jogou contra: ['SK', 'North']
# Em 2017-04-08, FaZe jogou contra: ['G2']
# Em 2017-04-09, FaZe jogou contra: ['HellRaisers', 'Astralis']
# Em 2017-04-13, FaZe jogou contra: ['North']
# Em 2017-04-18, FaZe jogou contra: ['mousesports']
# Em 2017-04-25, FaZe jogou contra: ['Virtus.pro']
# Em 2017-04-26, FaZe jogou contra: ['NiP']
# Em 2017-05-03, FaZe jogou contra: ['Renegades', 'Astralis']
# Em 2017-05-04, FaZe jogou contra: ['OpTic', 'North']
# Em 2017-05-06, FaZe jogou contra: ['Astralis']
# Em 2017-05-07, FaZe jogou contra: ['SK']
# Em 2017-05-10, FaZe jogou contra: ['HellRaisers']
# Em 2017-05-11, FaZe jogou contra: ['G2']
# Em 2017-05-17, FaZe jogou contra: ['Envy']
# Em 2017-05-18, FaZe jogou contra: ['G2']
# Em 2017-05-26, FaZe jogou contra: ['fnatic', 'Dignitas']
# Em 2017-05-28, FaZe jogou contra: ['Astralis']
# Em 2017-06-07, FaZe jogou contra: ['GODSENT']
# Em 2017-06-08, FaZe jogou contra: ['mousesports']
# Em 2017-06-23, FaZe jogou contra: ['OpTic', 'SK']
# Em 2017-06-24, FaZe jogou contra: ['G2']
# Em 2017-06-25, FaZe jogou contra: ['Cloud9', 'SK']
# Em 2017-07-04, FaZe jogou contra: ['Heroic', 'mousesports']
# Em 2017-07-05, FaZe jogou contra: ['fnatic']
# Em 2017-07-06, FaZe jogou contra: ['North', 'OpTic']
# Em 2017-07-07, FaZe jogou contra: ['Liquid']
# Em 2017-07-08, FaZe jogou contra: ['SK']
# Em 2017-07-16, FaZe jogou contra: ['BIG']
# Em 2017-07-17, FaZe jogou contra: ['mousesports']
# Em 2017-07-18, FaZe jogou contra: ['FlipSid3']
# Em 2017-08-22, FaZe jogou contra: ['G2']
# Em 2017-08-23, FaZe jogou contra: ['mousesports']
# Em 2017-08-24, FaZe jogou contra: ['BIG']
# Em 2017-08-25, FaZe jogou contra: ['Envy']
# Em 2017-08-30, FaZe jogou contra: ['NiP', 'mousesports']
# Em 2017-09-01, FaZe jogou contra: ['Gambit']
# Em 2017-09-09, FaZe jogou contra: ['Renegades', 'Natus Vincere']
# Em 2017-09-15, FaZe jogou contra: ['Virtus.pro', 'Astralis']
# Em 2017-09-16, FaZe jogou contra: ['Cloud9']
# Em 2017-09-17, FaZe jogou contra: ['Liquid']
# Em 2017-09-21, FaZe jogou contra: ['BIG']
# Em 2017-09-27, FaZe jogou contra: ['NiP']
# Em 2017-09-28, FaZe jogou contra: ['NiP']
# Em 2017-10-03, FaZe jogou contra: ['Heroic']
# Em 2017-10-04, FaZe jogou contra: ['North']
# Em 2017-10-05, FaZe jogou contra: ['NiP', 'HellRaisers']
# Em 2017-10-06, FaZe jogou contra: ['Heroic', 'Astralis']
# Em 2017-10-08, FaZe jogou contra: ['Heroic', 'NiP']
# Em 2017-10-11, FaZe jogou contra: ['Envy']
# Em 2017-10-13, FaZe jogou contra: ['North']
# Em 2017-10-14, FaZe jogou contra: ['Astralis']
# Em 2017-10-17, FaZe jogou contra: ['GODSENT']
# Em 2017-10-22, FaZe jogou contra: ['NiP']
# Em 2017-10-23, FaZe jogou contra: ['TYLOO']
# Em 2017-10-24, FaZe jogou contra: ['Gambit']
# Em 2017-10-25, FaZe jogou contra: ['SK', 'mousesports']
# Em 2017-10-26, FaZe jogou contra: ['Virtus.pro', 'Envy']
# Em 2017-10-29, FaZe jogou contra: ['fnatic']
# Em 2017-11-08, FaZe jogou contra: ['GODSENT', 'fnatic']
# Em 2017-11-09, FaZe jogou contra: ['Astralis']
# Em 2017-11-11, FaZe jogou contra: ['G2', 'Natus Vincere']
# Em 2017-11-15, FaZe jogou contra: ['Renegades', 'OpTic', 'G2']
# Em 2017-11-16, FaZe jogou contra: ['Liquid', 'Gambit']
# Em 2017-11-19, FaZe jogou contra: ['Cloud9', 'NiP']
# Em 2017-11-23, FaZe jogou contra: ['Virtus.pro']
# Em 2017-11-25, FaZe jogou contra: ['G2', 'NiP', 'North', 'SK', 'Astralis']
# Em 2017-12-05, FaZe jogou contra: ['Liquid', 'fnatic']
# Em 2017-12-06, FaZe jogou contra: ['HellRaisers', 'Luminosity', 'Astralis']
# Em 2017-12-09, FaZe jogou contra: ['fnatic']
# Em 2017-12-10, FaZe jogou contra: ['SK']
# Em 2017-12-15, FaZe jogou contra: ['Liquid', 'Astralis']
# Em 2017-12-16, FaZe jogou contra: ['Cloud9']
# Em 2017-12-17, FaZe jogou contra: ['mousesports', 'fnatic']
# Em 2018-01-12, FaZe jogou contra: ['Liquid']
# Em 2018-01-13, FaZe jogou contra: ['Vega Squadron']
# Em 2018-01-14, FaZe jogou contra: ['Quantum Bellator Fire']
# Em 2018-01-15, FaZe jogou contra: ['Natus Vincere']
# Em 2018-01-19, FaZe jogou contra: ['fnatic']
# Em 2018-01-20, FaZe jogou contra: ['Vega Squadron']
# Em 2018-01-21, FaZe jogou contra: ['SK']
# Em 2018-01-26, FaZe jogou contra: ['mousesports']
# Em 2018-01-27, FaZe jogou contra: ['Natus Vincere']
# Em 2018-01-28, FaZe jogou contra: ['Cloud9']
# Em 2018-02-13, FaZe jogou contra: ['G2', 'Astralis']
# Em 2018-02-14, FaZe jogou contra: ['Natus Vincere']
# Em 2018-02-15, FaZe jogou contra: ['AGO']
# Em 2018-02-17, FaZe jogou contra: ['TYLOO']
# Em 2018-02-18, FaZe jogou contra: ['Cloud9']
# Em 2018-02-19, FaZe jogou contra: ['Natus Vincere']
# Em 2018-02-23, FaZe jogou contra: ['Renegades']
# Em 2018-02-24, FaZe jogou contra: ['Natus Vincere']
# Em 2018-02-25, FaZe jogou contra: ['Liquid']
# Em 2018-02-27, FaZe jogou contra: ['ORDER']
# Em 2018-02-28, FaZe jogou contra: ['North']
# Em 2018-03-01, FaZe jogou contra: ['fnatic']
# Em 2018-03-02, FaZe jogou contra: ['Cloud9']
# Em 2018-03-03, FaZe jogou contra: ['Astralis']
# Em 2018-03-04, FaZe jogou contra: ['fnatic']
# Em 2018-03-13, FaZe jogou contra: ['mousesports', 'Virtus.pro']
# Em 2018-03-14, FaZe jogou contra: ['Heroic']
# Em 2018-03-15, FaZe jogou contra: ['mousesports', 'Astralis']
# Em 2018-03-23, FaZe jogou contra: ['GameAgents', 'HellRaisers', 'Dark Tigers']
# Em 2018-03-24, FaZe jogou contra: ['HellRaisers']
# Em 2018-03-25, FaZe jogou contra: ['Virtus.pro']
# Em 2018-04-03, FaZe jogou contra: ['Envy']
# Em 2018-04-04, FaZe jogou contra: ['North']
# Em 2018-04-05, FaZe jogou contra: ['NiP']
# Em 2018-04-06, FaZe jogou contra: ['fnatic']
# Em 2018-04-10, FaZe jogou contra: ['HellRaisers']
# Em 2018-04-11, FaZe jogou contra: ['Gambit', 'fnatic']
# Em 2018-04-12, FaZe jogou contra: ['LDLC']
# Em 2018-04-18, FaZe jogou contra: ['Envy']
# Em 2018-04-19, FaZe jogou contra: ['Cloud9']
# Em 2018-04-20, FaZe jogou contra: ['Envy']
# Em 2018-04-21, FaZe jogou contra: ['Astralis']
# Em 2018-04-24, FaZe jogou contra: ['G2']
# Em 2018-04-26, FaZe jogou contra: ['Space Soldiers']
# Em 2018-05-01, FaZe jogou contra: ['Renegades', 'ORDER']
# Em 2018-05-02, FaZe jogou contra: ['Grayhound']
# Em 2018-05-03, FaZe jogou contra: ['Cloud9']
# Em 2018-05-04, FaZe jogou contra: ['fnatic']
# Em 2018-05-05, FaZe jogou contra: ['TYLOO']
# Em 2018-05-06, FaZe jogou contra: ['Astralis']
# Em 2018-05-10, FaZe jogou contra: ['GODSENT', 'NiP']
# Em 2018-05-11, FaZe jogou contra: ['Envy']
# Em 2018-05-15, FaZe jogou contra: ['Cloud9', 'mousesports']
# Em 2018-05-17, FaZe jogou contra: ['Natus Vincere']
# Em 2018-05-18, FaZe jogou contra: ['SK']
# Em 2018-05-19, FaZe jogou contra: ['Astralis']
# Em 2018-06-08, FaZe jogou contra: ['NRG', 'Luminosity']
# Em 2018-06-09, FaZe jogou contra: ['G2']
# Em 2018-06-10, FaZe jogou contra: ['Astralis']
# Em 2018-06-13, FaZe jogou contra: ['Ghost']
# Em 2018-06-14, FaZe jogou contra: ['Space Soldiers']
# Em 2018-06-16, FaZe jogou contra: ['Liquid']
# Em 2018-06-17, FaZe jogou contra: ['mousesports']
# Em 2018-07-03, FaZe jogou contra: ['BOOT-d[S]']
# Em 2018-07-04, FaZe jogou contra: ['MIBR']
# Em 2018-07-05, FaZe jogou contra: ['fnatic']
# Em 2018-07-07, FaZe jogou contra: ['BIG']
# Em 2018-07-23, FaZe jogou contra: ['mousesports']
# Em 2018-07-24, FaZe jogou contra: ['fnatic']
# Em 2018-08-29, FaZe jogou contra: ['Heroic']
# Em 2018-08-30, FaZe jogou contra: ['OpTic']
# Em 2018-09-01, FaZe jogou contra: ['mousesports']
# Em 2018-09-12, FaZe jogou contra: ['BIG']
# Em 2018-09-13, FaZe jogou contra: ['Natus Vincere']
# Em 2018-09-14, FaZe jogou contra: ['mousesports']
# Em 2018-09-15, FaZe jogou contra: ['TYLOO']
# Em 2018-09-16, FaZe jogou contra: ['G2']
# Em 2018-09-21, FaZe jogou contra: ['Astralis']
# Em 2018-09-26, FaZe jogou contra: ['G2']
# Em 2018-09-27, FaZe jogou contra: ['NRG']
# Em 2018-10-04, FaZe jogou contra: ['Astralis', 'G2']
# Em 2018-10-05, FaZe jogou contra: ['AGO', 'Windigo']
# Em 2018-10-07, FaZe jogou contra: ['OpTic']
# Em 2018-10-10, FaZe jogou contra: ['LDLC']
# Em 2018-10-16, FaZe jogou contra: ['ex-Space Soldiers', 'fnatic']
# Em 2018-10-17, FaZe jogou contra: ['BIG', 'fnatic']
# Em 2018-10-18, FaZe jogou contra: ['Natus Vincere']
# Em 2018-10-19, FaZe jogou contra: ['HellRaisers', 'Astralis']
# Em 2018-10-20, FaZe jogou contra: ['North']
# Em 2018-10-21, FaZe jogou contra: ['mousesports']
# Em 2018-10-22, FaZe jogou contra: ['G2']
# Em 2018-10-23, FaZe jogou contra: ['ENCE']
# Em 2018-10-25, FaZe jogou contra: ['Natus Vincere']
# Em 2018-10-27, FaZe jogou contra: ['NiP']
# Em 2018-10-28, FaZe jogou contra: ['Liquid', 'Natus Vincere']
# Em 2018-10-30, FaZe jogou contra: ['Virtus.pro']
# Em 2018-10-31, FaZe jogou contra: ['NiP']
# Em 2018-11-01, FaZe jogou contra: ['North']
# Em 2018-11-02, FaZe jogou contra: ['Natus Vincere', 'NiP']
# Em 2018-11-03, FaZe jogou contra: ['Cloud9', 'Astralis', 'MIBR']
# Em 2018-11-06, FaZe jogou contra: ['LDLC']
# Em 2018-11-07, FaZe jogou contra: ['MIBR']
# Em 2018-11-08, FaZe jogou contra: ['Astralis']
# Em 2018-11-11, FaZe jogou contra: ['Liquid']
# Em 2018-11-14, FaZe jogou contra: ['mousesports', 'Heroic']
# Em 2018-12-14, FaZe jogou contra: ['Cloud9', 'Astralis']
# Em 2018-12-15, FaZe jogou contra: ['MIBR', 'Natus Vincere', 'NiP']
# Em 2019-01-20, FaZe jogou contra: ['Ghost', 'Luminosity']
# Em 2019-01-25, FaZe jogou contra: ['Cloud9']
# Em 2019-01-26, FaZe jogou contra: ['Complexity']
# Em 2019-01-27, FaZe jogou contra: ['BIG']
# Em 2019-01-28, FaZe jogou contra: ['Cloud9']
# Em 2019-02-20, FaZe jogou contra: ['HellRaisers', 'Renegades']
# Em 2019-02-21, FaZe jogou contra: ['AVANGAR']
# Em 2019-02-23, FaZe jogou contra: ['Complexity']
# Em 2019-02-24, FaZe jogou contra: ['Cloud9']
# Em 2019-02-28, FaZe jogou contra: ['Natus Vincere']
# Em 2019-03-11, FaZe jogou contra: ['Virtus.pro']
# Em 2019-03-13, FaZe jogou contra: ['NiP']
# Em 2019-03-22, FaZe jogou contra: ['NiP']
# Em 2019-03-23, FaZe jogou contra: ['MIBR', 'ENCE', 'Astralis', 'Liquid']
# Em 2019-03-30, FaZe jogou contra: ['paiN']
# Em 2019-03-31, FaZe jogou contra: ['ViCi']
# Em 2019-04-01, FaZe jogou contra: ['Renegades']
# Em 2019-04-02, FaZe jogou contra: ['ENCE']
# Em 2019-04-03, FaZe jogou contra: ['North']
# Em 2019-04-12, FaZe jogou contra: ['Liquid']
# Em 2019-04-13, FaZe jogou contra: ['MIBR', 'Liquid', 'Cloud9', 'Natus Vincere', 'Astralis']
# Em 2019-04-16, FaZe jogou contra: ['devils.one']
# Em 2019-04-17, FaZe jogou contra: ['Heroic']
# Em 2019-04-18, FaZe jogou contra: ['NiP']
# Em 2019-04-30, FaZe jogou contra: ['Chiefs']
# Em 2019-05-01, FaZe jogou contra: ['NRG']
# Em 2019-05-02, FaZe jogou contra: ['Grayhound']
# Em 2019-05-13, FaZe jogou contra: ['Virtus.pro']
# Em 2019-05-21, FaZe jogou contra: ['G2']
# Em 2019-05-23, FaZe jogou contra: ['OpTic']
# Em 2019-05-28, FaZe jogou contra: ['Windigo']
# Em 2019-05-29, FaZe jogou contra: ['NiP']
# Em 2019-05-30, FaZe jogou contra: ['Liquid']
# Em 2019-06-01, FaZe jogou contra: ['G2']
# Em 2019-06-02, FaZe jogou contra: ['ENCE']
# Em 2019-06-18, FaZe jogou contra: ['TYLOO']
# Em 2019-06-19, FaZe jogou contra: ['North']
# Em 2019-06-20, FaZe jogou contra: ['mousesports']
# Em 2019-06-21, FaZe jogou contra: ['G2']
# Em 2019-07-02, FaZe jogou contra: ['Renegades', 'NRG']
# Em 2019-07-03, FaZe jogou contra: ['mousesports']
# Em 2019-07-13, FaZe jogou contra: ['NRG', 'Renegades']
# Em 2019-07-14, FaZe jogou contra: ['MIBR', 'Liquid', 'Cloud9', 'NRG']
# Em 2019-07-15, FaZe jogou contra: ['Liquid']
# Em 2019-08-28, FaZe jogou contra: ['mousesports']
# Em 2019-08-29, FaZe jogou contra: ['Vitality']
# Em 2019-08-30, FaZe jogou contra: ['CR4ZY']
# Em 2019-08-31, FaZe jogou contra: ['Renegades']
# Em 2019-09-26, FaZe jogou contra: ['Evil Geniuses']
# Em 2019-09-27, FaZe jogou contra: ['OpTic']
# Em 2019-10-08, FaZe jogou contra: ['OpTic']
# Em 2019-10-09, FaZe jogou contra: ['BIG']
# Em 2019-10-10, FaZe jogou contra: ['mousesports']
# Em 2019-10-14, FaZe jogou contra: ['BIG']
# Em 2019-10-21, FaZe jogou contra: ['Virtus.pro']
# Em 2019-10-22, FaZe jogou contra: ['Astralis']
# Em 2019-10-28, FaZe jogou contra: ['Heroic']
# Em 2019-10-29, FaZe jogou contra: ['Virtus.pro']
# Em 2019-11-01, FaZe jogou contra: ['Astralis', 'Natus Vincere']
# Em 2019-11-02, FaZe jogou contra: ['Cloud9', 'NiP', 'Liquid']
# Em 2019-11-07, FaZe jogou contra: ['Evil Geniuses']
# Em 2019-11-08, FaZe jogou contra: ['Evil Geniuses', 'Vitality']
# Em 2019-11-09, FaZe jogou contra: ['Astralis']
# Em 2019-11-16, FaZe jogou contra: ['Vitality']
# Em 2019-11-17, FaZe jogou contra: ['HellRaisers']
# Em 2019-11-18, FaZe jogou contra: ['fnatic']
# Em 2019-12-03, FaZe jogou contra: ['MIBR', 'TYLOO']
# Em 2019-12-04, FaZe jogou contra: ['100 Thieves']
# Em 2019-12-12, FaZe jogou contra: ['NiP']
# Em 2019-12-13, FaZe jogou contra: ['Liquid']
# Em 2020-01-09, FaZe jogou contra: ['ARCY', 'ENCE']
# Em 2020-01-31, FaZe jogou contra: ['NiP']
# Em 2020-02-01, FaZe jogou contra: ['Liquid']
# Em 2020-02-02, FaZe jogou contra: ['Liquid']
# Em 2020-02-24, FaZe jogou contra: ['Natus Vincere']
# Em 2020-02-25, FaZe jogou contra: ['Renegades']
# Em 2020-02-26, FaZe jogou contra: ['Vitality']
# Em 2020-02-27, FaZe jogou contra: ['Natus Vincere']
# FaZe não jogou em 2020-03-18.

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Define equipe para analisar e o ano específico
team_to_analyze = 'Liquid'  # Substitua pelo nome da equipe desejada
specific_year = 2020  # Substitua pelo ano desejado para análise

# Carregar dados do CSV
df = pd.read_csv('../db/results.csv')

# Converter as datas para o tipo datetime e adicionar uma coluna 'year'
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# Filtrar as partidas que incluem a equipe de interesse e ocorreram no ano específico
df_team_year = df[((df['team_1'] == team_to_analyze) | (df['team_2'] == team_to_analyze)) & (df['year'] == specific_year)]

# Criar um grafo para o ano especificado
G_year = nx.Graph()
for i, row in df_team_year.iterrows():
    # Adiciona equipe adversária como nó no grafo
    opponent = row['team_2'] if row['team_1'] == team_to_analyze else row['team_1']
    G_year.add_edge(team_to_analyze, opponent, weight=1)

# Visualização do grafo para o ano especificado
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G_year)  # Isso pode levar algum tempo para grafos grandes
nx.draw_networkx_nodes(G_year, pos, node_size=500, node_color='lightblue')
nx.draw_networkx_edges(G_year, pos, edge_color='gray')
nx.draw_networkx_labels(G_year, pos, font_size=10)
plt.title(f'Conexões de {team_to_analyze} no ano de {specific_year}')
plt.axis('off')
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

team_to_analyze = 'SK'  # Defina a equipe para analisar

# Carregar dados do CSV
df = pd.read_csv('../db/results.csv')

# Converter as datas para o tipo datetime e adicionar uma coluna 'year'
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# Filtrar as partidas que incluem a equipe de interesse
df_team = df[(df['team_1'] == team_to_analyze) | (df['team_2'] == team_to_analyze)]

# Agrupar as partidas por ano e criar um grafo para cada ano
graphs_by_year = {}
for year, group in df_team.groupby('year'):
    G = nx.Graph()
    for i, row in group.iterrows():
        opponent = row['team_2'] if row['team_1'] == team_to_analyze else row['team_1']
        G.add_edge(team_to_analyze, opponent)
    graphs_by_year[year] = G

# Configuração da visualização
fig, axes = plt.subplots(nrows=1, ncols=len(graphs_by_year), figsize=(15, 5))
fig.suptitle(f'Conexões Anuais de {team_to_analyze}', fontsize=16)

# Criar um gráfico para cada ano
for ax, (year, G) in zip(axes, graphs_by_year.items()):
    pos = nx.spring_layout(G, seed=42)  # Fornece um layout consistente
    nx.draw_networkx_nodes(G, pos, ax=ax, node_size=100, node_color='lightblue')
    nx.draw_networkx_edges(G, pos, ax=ax, edge_color='gray')
    nx.draw_networkx_labels(G, pos, ax=ax, font_size=8)
    ax.set_title(str(year))
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Carregar dados do CSV
df = pd.read_csv('../db/results.csv')

# Convertendo as colunas de resultado para inteiros e datas para datetime
df['result_1'] = pd.to_numeric(df['result_1'], errors='coerce')
df['result_2'] = pd.to_numeric(df['result_2'], errors='coerce')
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# Limiar para considerar uma conexão significativa
minRivalry = 20

# Agrupar os dados por ano
grouped = df.groupby('year')

# Criar um grafo para cada ano
graphs_by_year = {}
for year, group in grouped:
    G = nx.Graph()
    for index, row in group.iterrows():
        score_diff = abs(row['result_1'] - row['result_2'])
        weight = 1 if score_diff == 0 else 1 / score_diff
        
        if row['map_winner'] == '1':
            weight += 1
        elif row['map_winner'] == '2':
            weight += 1
        
        if G.has_edge(row['team_1'], row['team_2']):
            G.edges[row['team_1'], row['team_2']]['weight'] += weight
        else:
            G.add_edge(row['team_1'], row['team_2'], weight=weight)
    graphs_by_year[year] = G

# Configuração da visualização
num_years = len(graphs_by_year)
fig, axes = plt.subplots(nrows=1, ncols=num_years, figsize=(num_years * 5, 5))
if num_years == 1:
    axes = [axes]

fig.suptitle('Rede de Competição de CSGO com Conexões Fortes por Ano', fontsize=16)

# Criar um gráfico para cada ano
for ax, (year, G) in zip(axes, graphs_by_year.items()):
    pos = nx.spring_layout(G, seed=42)
    
    # Verificar se o grafo tem arestas e se os pesos são válidos
    if G.edges and nx.get_edge_attributes(G, 'weight'):
        edges, weights = zip(*nx.get_edge_attributes(G, 'weight').items())
        
        # Verificar se todos os pesos não são zero
        if all(weight > 0 for weight in weights):
            nx.draw_networkx_nodes(G, pos, ax=ax, node_size=100, node_color='lightblue')
            nx.draw_networkx_edges(G, pos, ax=ax, edgelist=edges, edge_color=weights, width=2.0, edge_cmap=plt.cm.Blues)
            nx.draw_networkx_labels(G, pos, ax=ax, font_size=8)
        else:
            ax.text(0.5, 0.5, 'Conexões insuficientes', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
    else:
        ax.text(0.5, 0.5, 'Sem partidas neste ano', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
    
    ax.set_title(str(year))
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Defina a equipe para analisar
team_to_analyze = 'SK'

# Carregar dados do CSV
df = pd.read_csv('../db/results.csv')

# Convertendo as colunas de resultado para inteiros e datas para datetime
df['result_1'] = pd.to_numeric(df['result_1'], errors='coerce')
df['result_2'] = pd.to_numeric(df['result_2'], errors='coerce')
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# Filtrar as partidas que incluem a equipe especificada
df_filtered = df[(df['team_1'] == team_to_analyze) | (df['team_2'] == team_to_analyze)]

minRivalry = 300

# Agrupar os dados filtrados por ano
grouped = df_filtered.groupby('year')

graphs_by_year = {}
for year, group in grouped:
    G = nx.Graph()
    for index, row in group.iterrows():
        score_diff = abs(row['result_1'] - row['result_2'])
        weight = 1 if score_diff == 0 else 1 / score_diff
        
        if row['map_winner'] == '1':
            weight += 1
        elif row['map_winner'] == '2':
            weight += 1
        
        opponent = row['team_2'] if row['team_1'] == team_to_analyze else row['team_1']
        if G.has_edge(team_to_analyze, opponent):
            G.edges[team_to_analyze, opponent]['weight'] += weight
        else:
            G.add_edge(team_to_analyze, opponent, weight=weight)
    graphs_by_year[year] = G

# Verificar se há dados suficientes para criar subplots
if not graphs_by_year:
    print(f"Não foram encontradas partidas para a equipe {team_to_analyze} em nenhum ano.")
else:
    num_years = len(graphs_by_year)
    fig, axes = plt.subplots(nrows=1, ncols=num_years, figsize=(num_years * 5, 5))
    if num_years == 1:
        axes = [axes]

    fig.suptitle(f'Rede de Competição de {team_to_analyze} com Conexões Fortes por Ano', fontsize=16)

    for ax, (year, G) in zip(axes, graphs_by_year.items()):
        pos = nx.spring_layout(G, seed=42)
        if G.edges and nx.get_edge_attributes(G, 'weight'):
            edges, weights = zip(*nx.get_edge_attributes(G, 'weight').items())
            if all(weight > 0 for weight in weights):
                nx.draw_networkx_nodes(G, pos, ax=ax, node_size=100, node_color='lightblue')
                nx.draw_networkx_edges(G, pos, ax=ax, edgelist=edges, edge_color=weights, width=2.0, edge_cmap=plt.cm.Blues)
                nx.draw_networkx_labels(G, pos, ax=ax, font_size=8)
            else:
                ax.text(0.5, 0.5, 'Conexões insuficientes', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        else:
            ax.text(0.5, 0.5, 'Sem partidas neste ano', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        
        ax.set_title(str(year))
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

team_to_analyze = 'SK'  # Nome da equipe
df = pd.read_csv('../db/results.csv')

# Conversões necessárias
df['result_1'] = pd.to_numeric(df['result_1'], errors='coerce')
df['result_2'] = pd.to_numeric(df['result_2'], errors='coerce')
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# Filtragem por equipe
df_filtered = df[(df['team_1'] == team_to_analyze) | (df['team_2'] == team_to_analyze)]

minRivalry = 1  # Limiar de rivalidade

# Agrupamento por ano e construção do grafo
graphs_by_year = {}
for year, group in df_filtered.groupby('year'):
    G = nx.Graph()
    for index, row in group.iterrows():
        # Cálculo do peso
        score_diff = abs(row['result_1'] - row['result_2'])
        weight = 1 if score_diff == 0 else 1 / score_diff
        if row['map_winner'] == '1':
            weight += 1
        elif row['map_winner'] == '2':
            weight += 1
        
        opponent = row['team_2'] if row['team_1'] == team_to_analyze else row['team_1']
        if G.has_edge(team_to_analyze, opponent):
            G.edges[team_to_analyze, opponent]['weight'] += weight
        else:
            G.add_edge(team_to_analyze, opponent, weight=weight)

    # Filtragem por minRivalry
    H = nx.Graph([(u, v, d) for u, v, d in G.edges(data=True) if d['weight'] > minRivalry])
    graphs_by_year[year] = H

# Visualização
num_years = len(graphs_by_year)
if num_years == 0:
    print(f"Não foram encontradas partidas para a equipe {team_to_analyze} em nenhum ano.")
else:
    fig, axes = plt.subplots(nrows=1, ncols=num_years, figsize=(num_years * 5, 5))
    if num_years == 1:
        axes = [axes]

    fig.suptitle(f'Rede de Competição de {team_to_analyze} com Conexões Fortes por Ano', fontsize=16)

    for ax, (year, H) in zip(axes, graphs_by_year.items()):
        pos = nx.spring_layout(H, seed=42)
        if H.edges:
            nx.draw_networkx(H, pos, ax=ax, with_labels=True, node_size=500, node_color='lightblue', edge_color='gray')
        else:
            ax.text(0.5, 0.5, 'Sem conexões fortes', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.set_title(str(year))
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

team_to_analyze = 'FaZe'  # Nome da equipe
df = pd.read_csv('../db/results.csv')

# Conversões necessárias
df['result_1'] = pd.to_numeric(df['result_1'], errors='coerce')
df['result_2'] = pd.to_numeric(df['result_2'], errors='coerce')
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# Filtragem por equipe
df_filtered = df[(df['team_1'] == team_to_analyze) | (df['team_2'] == team_to_analyze)]

minRivalry = 1  # Limiar de rivalidade

# Agrupamento por ano e construção do grafo
graphs_by_year = {}
for year, group in df_filtered.groupby('year'):
    G = nx.Graph()
    for index, row in group.iterrows():
        # Cálculo do peso
        score_diff = abs(row['result_1'] - row['result_2'])
        weight = 1 if score_diff == 0 else 1 / score_diff
        if row['map_winner'] == '1':
            weight += 1
        elif row['map_winner'] == '2':
            weight += 1
        
        opponent = row['team_2'] if row['team_1'] == team_to_analyze else row['team_1']
        if G.has_edge(team_to_analyze, opponent):
            G.edges[team_to_analyze, opponent]['weight'] += weight
        else:
            G.add_edge(team_to_analyze, opponent, weight=weight)

    # Filtragem por minRivalry
    H = nx.Graph([(u, v, d) for u, v, d in G.edges(data=True) if d['weight'] > minRivalry])
    graphs_by_year[year] = H

# Verificar se há dados suficientes para criar subplots
if not graphs_by_year:
    print(f"Não foram encontradas partidas para a equipe {team_to_analyze} em nenhum ano.")
else:
    for year, H in graphs_by_year.items():
        plt.figure(figsize=(5, 5))
        pos = nx.spring_layout(H, seed=42)
        if H.edges:
            nx.draw_networkx_nodes(H, pos, node_size=500, node_color='lightblue')
            nx.draw_networkx_edges(H, pos, edge_color='gray')
            nx.draw_networkx_labels(H, pos, font_size=8)

            # Formatar e desenhar rótulos de peso nas arestas
            edge_weights = nx.get_edge_attributes(H, 'weight')
            formatted_edge_weights = {e: f"{w:.2f}" for e, w in edge_weights.items()}
            nx.draw_networkx_edge_labels(H, pos, edge_labels=formatted_edge_weights, font_size=8)
        else:
            plt.text(0.5, 0.5, 'Sem conexões fortes', horizontalalignment='center', verticalalignment='center')
        
        plt.title(f'Rede de Competição de {team_to_analyze} - Ano {year}', fontsize=12)
        plt.axis('off')
        plt.show()
